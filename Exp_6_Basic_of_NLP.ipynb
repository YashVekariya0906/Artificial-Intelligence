# %%
# NLP EXPERIMENT FULL CODE (FINAL FIXED)
import nltk
import string
import spacy
# DOWNLOAD REQUIRED NLTK DATA
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag, RegexpParser

# LOAD SPACY MODEL
nlp = spacy.load("en_core_web_sm")

# INPUT TEXT
text = input("Enter a sentence: ")
print("\nOriginal Text:\n", text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# Enter a sentence: Dolls powered by artificial intelligence that can just up and get a mind of their own one day.
#
# Original Text:
#  Dolls powered by artificial intelligence that can just up and get a mind of their own one day.

# %%
# 1. TOKENIZATION
tokens = word_tokenize(text)
print("\n1. Tokens:\n", tokens)
# Out:
# 1. Tokens:
#  ['Dolls', 'powered', 'by', 'artificial', 'intelligence', 'that', 'can', 'just', 'up', 'and', 'get', 'a', 'mind', 'of', 'their', 'own', 'one', 'day', '.']

# %%
# 2. FILTRATION (REMOVE PUNCTUATION)
filtered_tokens = [word for word in tokens if word not in string.punctuation]
print("\n2. Filtered Tokens:\n", filtered_tokens)
# Out:
# 2. Filtered Tokens:
#  ['Dolls', 'powered', 'by', 'artificial', 'intelligence', 'that', 'can', 'just', 'up', 'and', 'get', 'a', 'mind', 'of', 'their', 'own', 'one', 'day']

# %%
# 3. STOPWORDS REMOVAL
stop_words = set(stopwords.words('english'))
clean_tokens = [word for word in filtered_tokens if word.lower() not in stop_words]
print("\n3. After Stopword Removal:\n", clean_tokens)
# Out:
# 3. After Stopword Removal:
#  ['Dolls', 'powered', 'artificial', 'intelligence', 'get', 'mind', 'one', 'day']

# %%
# 4. POS TAGGING
pos_tags = pos_tag(clean_tokens)
print("\n4. POS Tags:\n", pos_tags)
# Out:
# 4. POS Tags:
#  [('Dolls', 'NNS'), ('powered', 'VBD'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('get', 'NN'), ('mind', 'VB'), ('one', 'CD'), ('day', 'NN')]

# %%
# 5. NOUN PHRASE CHUNKING
grammar = "NP: {<DT>?<JJ>*<NN.*>+}"
chunk_parser = RegexpParser(grammar)
chunk_tree = chunk_parser.parse(pos_tags)

print("\n5. Noun Phrase Chunking:\n")
print(chunk_tree)
# Out:
# 5. Noun Phrase Chunking:
#
# (S
#   (NP Dolls/NNS)
#   powered/VBD
#   (NP artificial/JJ intelligence/NN get/NN)
#   mind/VB
#   one/CD
#   (NP day/NN))

# %%
# 6. DEPENDENCY PARSING (spaCy)
doc = nlp(text)

print("\n6. Dependency Parsing:\n")
for token in doc:
    print(f"{token.text} --> {token.dep_} --> {token.head.text}")
# Out:
# 6. Dependency Parsing:
#
# Dolls --> ROOT --> Dolls
# powered --> acl --> Dolls
# by --> agent --> powered
# artificial --> amod --> intelligence
# intelligence --> pobj --> by
# that --> nsubj --> up
# can --> aux --> up
# just --> advmod --> up
# up --> relcl --> Dolls
# and --> cc --> up
# get --> conj --> up
# a --> det --> mind
# mind --> dobj --> get
# of --> prep --> mind
# their --> poss --> day
# own --> amod --> day
# one --> nummod --> day
# day --> pobj --> of
# . --> punct --> Dolls

# %%
# Take your own document of 10 sentences and perform the same tasks. Attach code and screenshot of your output.
import nltk
import string
import spacy

# Download required data
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag, RegexpParser
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Load spacy
nlp = spacy.load("en_core_web_sm")

# INPUT DOCUMENT (10 sentences)
text = """Peacock is beautiful bird
Sparrow is a small bird
Dog is a loyal animal
Cat drinks milk daily
Sun gives us light
Moon shines at night
Boy plays in garden
Girl reads a book
Water is very important
Trees give us oxygen"""

print("Original Text:\n", text)

# TOKENIZATION
tokens = word_tokenize(text)
print("\nTokens:\n", tokens)

# FILTERING
filtered = [w for w in tokens if w not in string.punctuation]

# STOPWORDS REMOVAL
stop_words = set(stopwords.words('english'))
clean_tokens = [w for w in filtered if w.lower() not in stop_words]
print("\nClean Tokens:\n", clean_tokens)

# POS TAGGING
pos_tags = pos_tag(clean_tokens)
print("\nPOS Tags:\n", pos_tags)

# NOUN PHRASE CHUNKING
grammar = "NP: {<DT>?<JJ>*<NN.*>+}"
cp = RegexpParser(grammar)
tree = cp.parse(pos_tags)
print("\nChunk Tree:\n", tree)

# DEPENDENCY PARSING
doc = nlp(text)
print("\nDependency Parsing:\n")
for token in doc:
    print(token.text, "->", token.dep_, "->", token.head.text)

# STEMMING
stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in clean_tokens]

print("\nStemming:\n", stemmed)

# LEMMATIZATION
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in clean_tokens]

print("\nLemmatization:\n", lemmatized)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Original Text:
#  Peacock is beautiful bird
# Sparrow is a small bird
# Dog is a loyal animal
# Cat drinks milk daily
# Sun gives us light
# Moon shines at night
# Boy plays in garden
# Girl reads a book
# Water is very important
# Trees give us oxygen
#
# Tokens:
#  ['Peacock', 'is', 'beautiful', 'bird', 'Sparrow', 'is', 'a', 'small', 'bird', 'Dog', 'is', 'a', 'loyal', 'animal', 'Cat', 'drinks', 'milk', 'daily', 'Sun', 'gives', 'us', 'light', 'Moon', 'shines', 'at', 'night', 'Boy', 'plays', 'in', 'garden', 'Girl', 'reads', 'a', 'book', 'Water', 'is', 'very', 'important', 'Trees', 'give', 'us', 'oxygen']
#
# Clean Tokens:
#  ['Peacock', 'beautiful', 'bird', 'Sparrow', 'small', 'bird', 'Dog', 'loyal', 'animal', 'Cat', 'drinks', 'milk', 'daily', 'Sun', 'gives', 'us', 'light', 'Moon', 'shines', 'night', 'Boy', 'plays', 'garden', 'Girl', 'reads', 'book', 'Water', 'important', 'Trees', 'give', 'us', 'oxygen']
#
# POS Tags:
#  [('Peacock', 'NNP'), ('beautiful', 'JJ'), ('bird', 'NN'), ('Sparrow', 'NNP'), ('small', 'JJ'), ('bird', 'NN'), ('Dog', 'NNP'), ('loyal', 'VBZ'), ('animal', 'JJ'), ('Cat', 'NNP'), ('drinks', 'NNS'), ('milk', 'VBD'), ('daily', 'JJ'), ('Sun', 'NNP'), ('gives', 'VBZ'), ('us', 'PRP'), ('light', 'JJ'), ('Moon', 'NNP'), ('shines', 'NNS'), ('night', 'NN'), ('Boy', 'NNP'), ('plays', 'VBZ'), ('garden', 'NN'), ('Girl', 'NNP'), ('reads', 'VBZ'), ('book', 'NN'), ('Water', 'NNP'), ('important', 'JJ'), ('Trees', 'NNP'), ('give', 'VBP'), ('us', 'PRP'), ('oxygen', 'NN')]
#
# Chunk Tree:
#  (S
#   (NP Peacock/NNP)
#   (NP beautiful/JJ bird/NN Sparrow/NNP)
#   (NP small/JJ bird/NN Dog/NNP)
#   loyal/VBZ
#   (NP animal/JJ Cat/NNP drinks/NNS)
#   milk/VBD
#   (NP daily/JJ Sun/NNP)
#   gives/VBZ
#   us/PRP
#   (NP light/JJ Moon/NNP shines/NNS night/NN Boy/NNP)
#   plays/VBZ
#   (NP garden/NN Girl/NNP)
#   reads/VBZ
#   (NP book/NN Water/NNP)
#   (NP important/JJ Trees/NNP)
#   give/VBP
#   us/PRP
#   (NP oxygen/NN))
#
# Dependency Parsing:
#
# Peacock -> nsubj -> is
# is -> ROOT -> is
# beautiful -> amod -> bird
# bird -> compound -> Sparrow
#
#  -> dep -> bird
# Sparrow -> nsubj -> is
# is -> ccomp -> is
# a -> det -> Dog
# small -> amod -> bird
# bird -> compound -> Dog
#
#  -> dep -> bird
# Dog -> nsubj -> is
# is -> ccomp -> is
# a -> det -> animal
# loyal -> amod -> animal
# animal -> compound -> Cat
#
#  -> dep -> animal
# Cat -> nsubj -> drinks
# drinks -> ccomp -> is
# milk -> compound -> Sun
# daily -> amod -> Sun
#
#  -> dep -> daily
# Sun -> nsubj -> gives
# gives -> ROOT -> gives
# us -> dative -> gives
# light -> amod -> Moon
#
#  -> dep -> light
# Moon -> dobj -> gives
# shines -> ccomp -> gives
# at -> prep -> shines
# night -> pobj -> at
#
#  -> dep -> night
# Boy -> nsubj -> plays
# plays -> ROOT -> plays
# in -> prep -> plays
# garden -> compound -> Girl
#
#  -> dep -> garden
# Girl -> pobj -> in
# reads -> advcl -> plays
# a -> det -> Water
# book -> compound -> Water
#
#  -> dep -> book
# Water -> nsubj -> is
# is -> ccomp -> reads
# very -> advmod -> important
# important -> amod -> Trees
#
#  -> dep -> important
# Trees -> nsubj -> give
# give -> ccomp -> is
# us -> dative -> give
# oxygen -> dobj -> give
#
# Stemming:
#  ['peacock', 'beauti', 'bird', 'sparrow', 'small', 'bird', 'dog', 'loyal', 'anim', 'cat', 'drink', 'milk', 'daili', 'sun', 'give', 'us', 'light', 'moon', 'shine', 'night', 'boy', 'play', 'garden', 'girl', 'read', 'book', 'water', 'import', 'tree', 'give', 'us', 'oxygen']
#
# Lemmatization:
#  ['Peacock', 'beautiful', 'bird', 'Sparrow', 'small', 'bird', 'Dog', 'loyal', 'animal', 'Cat', 'drink', 'milk', 'daily', 'Sun', 'give', 'u', 'light', 'Moon', 'shine', 'night', 'Boy', 'play', 'garden', 'Girl', 'read', 'book', 'Water', 'important', 'Trees', 'give', 'u', 'oxygen']
